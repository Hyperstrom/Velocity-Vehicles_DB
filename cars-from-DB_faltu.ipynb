# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
import configparser
# Define DB credentials
# Read database credentials from db.properties
import mysql.connector
config = configparser.ConfigParser()
config.read('db.properties')

db_config = {
    'host': config.get('mysql', 'host'),
    'user': config.get('mysql', 'user'),
    'password': config.get('mysql', 'password')
}

# %%
# Connect to the MySQL database using db_config
conn = mysql.connector.connect(
    host=db_config['host'],
    user=db_config['user'],
    password=db_config['password'],
    database='velocity_vehicles'
)
cursor = conn.cursor()

# %%
# Fetch and print all column names along with their SQL data types from the 'cars' table
cursor.execute("SHOW COLUMNS FROM cars")
for col in cursor.fetchall():
    print(f"{col[0]}: {col[1]}")
# Out:
# car_id: varchar(255)
# brand_id: varchar(255)
# dealer_username: varchar(100)
# model: varchar(100)
# variant: varchar(100)
# price_inr: decimal(15,2)
# engine(CC): int
# cylinders: int
# fuel_capacity: int
# fuel_type: varchar(100)
# body_type: varchar(100)
# mileage: float
# gears: int
# power_steering: varchar(100)
# keyless_entry: tinyint(1)
# power(HP): float
# torque(NM): float
# seating_capacity: int
# transmission_type: varchar(100)
# warranty: int
# sun_visor: tinyint(1)
# ventilation_system: tinyint(1)
# abs: tinyint(1)
# airbags: tinyint(1)
# colour: varchar(100)
# status: varchar(20)

# %%
# Fetch and print 10 random BMW cars from the database
query = """
SELECT c.Car_id, b.car_brand, c.model, c.variant, c.dealer_username, c.Price_INR, c.`Engine(CC)`, c.Cylinders, c.Fuel_capacity, c.Fuel_type, c.Body_type, c.Mileage, c.Gears, c.Power_steering, c.Keyless_entry, c.`Power(HP)`, c.`Torque(NM)`, c.Seating_capacity, c.Transmission_type, c.warranty, c.Sun_visor, c.Ventilation_system, c.ABS, c.Airbags, c.Colour, c.Status
FROM cars c
JOIN car_brands b ON c.Brand_ID = b.brand_id
ORDER BY RAND()
"""
cursor.execute(query)
rows = cursor.fetchall()

for row in rows:
    formatted_items = []
    for item in row:
        if item == 1:
            formatted_items.append("true")
        elif item == 0:
            formatted_items.append("false")
        elif isinstance(item, str):
            formatted_items.append(f'"{item}"')
        else:
            formatted_items.append(str(item))
    formatted = ', '.join(formatted_items)
    print("new Car("+formatted+", carImageService.getCarImageSrc("+formatted_items[0]+")),")

# %%
# Fetch and print all column names along with their SQL data types from the 'car_brands' table
cursor.execute("SHOW COLUMNS FROM car_brands")
for col in cursor.fetchall():
    print(f"{col[0]}: {col[1]}")
# Out:
# car_brand: varchar(50)
# brand_id: varchar(255)

# %%
# Fetch and print 10 random BMW cars from the database
query = """
SELECT c.Car_id, b.car_brand, c.model, c.variant
FROM cars c
JOIN car_brands b ON c.Brand_ID = b.brand_id
ORDER BY RAND()
"""
cursor.execute(query)
rows = cursor.fetchall()

for row in rows:
    formatted_items = []
    for item in row:
        if item == 1:
            formatted_items.append("true")
        elif item == 0:
            formatted_items.append("false")
        elif isinstance(item, str):
            formatted_items.append(f'"{item}"')
        else:
            formatted_items.append(str(item))
    formatted = ', '.join(formatted_items)

df_cars = pd.DataFrame(rows, columns=['car_id', 'brand', 'model', 'variant'])
df_cars.head()
# Out:
#       car_id          brand     model                                 variant
# 0  7-SEECD6C            Bmw  7-Series  730Ld Design Pure Excellence Signature
# 1  AMA2E1405          Honda     Amaze                             E Mt Petrol
# 2  CIAEB8722  Maruti Suzuki      Ciaz                               1.5L Zeta
# 3  TUC7D2599        Hyundai    Tucson                           2Wd Mt Diesel
# 4  VENCD8EAA        Hyundai     Venue                  1.0 Turbo Gdi Mt Sx(O)

# %%
import re
import os
import pandas as pd # Import pandas for DataFrame handling

def parse_old_car_data(car_data_string):
    """
    Parses the string containing old Car object instantiations and extracts
    carId, carName, and modelVariant.
    """
    cars = []
    # Regex to capture carId, carName, model_version, model_variant, and image_old_id_from_src
    # It looks for patterns like: new Car("OLD_ID", "CarName", "ModelVersion", "ModelVariant", ...
    # The regex is quite specific to the number of arguments in your Car constructor.
    pattern = re.compile(r'new Car\("([^"]+)",\s*"([^"]+)",\s*"([^"]+)",\s*"([^"]*)",\s*"([^"]+)",\s*([\d.]+),\s*(\d+),\s*(\d+),\s*(\d+),\s*"([^"]+)",\s*"([^"]+)",\s*([\d.]+),\s*(\d+),\s*"([^"]+)",\s*(true|false),\s*([\d.]+),\s*([\d.]+),\s*(\d+),\s*"([^"]+)",\s*(\d+),\s*(true|false),\s*(true|false),\s*(true|false),\s*(true|false),\s*"([^"]+)",\s*"([^"]+)",\s*carImageService\.getCarImageSrc\("([^"]+)"\)\)')

    matches = pattern.finditer(car_data_string)
    for match in matches:
        (old_car_id, car_name, model_version, model_variant, dealer_id, price, engine_displacement,
         num_cylinders, fuel_tank_capacity, fuel_type, body_type, mileage, seating_capacity,
         steering_type, ac, max_power, max_torque, gears, transmission_type, num_airbags,
         power_windows, abs, central_locking, alloy_wheels, color, availability,
         image_old_id) = match.groups()

        cars.append({
            "old_car_id": old_car_id,
            "car_name": car_name,
            "model_version": model_version, # This is the "Aspire" or "Kuv100 Nxt" part
            "model_variant": model_variant, # This is the specific variant like "1.5 Tdci Blu"
            "full_match": f"{car_name} {model_variant}", # Used for matching: "Ford 1.5 Tdci Blu"
            "original_line": match.group(0), # Keep the original line for replacement
            "image_old_id_from_src": image_old_id # The ID used in getCarImageSrc
        })
    return cars

def get_new_car_data(df_cars):
    """
    Fetches new car data from the provided DataFrame.
    This function expects df_cars to have 'car_id', 'brand', and 'variant' columns.
    It renames 'brand' to 'car_name' and 'variant' to 'model_variant' for
    consistency with the rest of the script.
    """
    # Create a copy to avoid modifying the original DataFrame outside this function
    temp_df = df_cars.copy()

    # Ensure required columns are present in the input DataFrame
    required_cols = ['car_id', 'brand', 'variant']
    if not all(col in temp_df.columns for col in required_cols):
        raise ValueError(f"df_cars DataFrame must contain {required_cols} columns.")
    
    # Rename columns to match the expected keys ('car_name', 'model_variant')
    # used by the matching logic in generate_updated_car_definitions and rename_car_images
    temp_df = temp_df.rename(columns={'brand': 'car_name', 'variant': 'model_variant'})

    # After renaming, ensure the keys expected by the rest of the script are present
    if not all(col in temp_df.columns for col in ['car_id', 'car_name', 'model_variant']):
        # This check is mostly for robustness, should pass if previous check and rename work
        raise ValueError("Error after renaming columns. Expected 'car_id', 'car_name', and 'model_variant'.")
    
    return temp_df.to_dict(orient='records')

def generate_updated_car_definitions(old_car_data, new_car_data):
    """
    Matches old car data with new car data and generates updated Car object definitions.
    """
    updated_definitions = []
    # Create a map for quick lookup: "CarName ModelVariant" -> new_car_id
    new_car_map = {f"{car['car_name']} {car['model_variant']}": car['car_id'] for car in new_car_data}

    for old_car in old_car_data:
        full_match_key = old_car["full_match"]
        if full_match_key in new_car_map:
            new_car_id = new_car_map[full_match_key]
            # Replace the old_car_id (the first argument in new Car)
            # and the image_old_id_from_src (in getCarImageSrc) with the new_car_id
            
            # Use re.sub for more precise replacement, especially for the first ID.
            # We target the specific pattern for the first ID in the Car constructor.
            # This makes sure we don't accidentally replace part of another string.
            updated_line = re.sub(
                r'new Car\("' + re.escape(old_car["old_car_id"]) + r'"',
                f'new Car("{new_car_id}"',
                old_car["original_line"],
                count=1 # Replace only the first occurrence
            )
            
            # Then replace the ID in carImageService.getCarImageSrc
            updated_line = updated_line.replace(
                f'carImageService.getCarImageSrc("{old_car["image_old_id_from_src"]}")',
                f'carImageService.getCarImageSrc("{new_car_id}")'
            )
            updated_definitions.append(updated_line)
        else:
            print(f"Warning: No new ID found for {old_car['car_name']} {old_car['model_variant']}. Keeping old definition.")
            updated_definitions.append(old_car["original_line"])
    return updated_definitions

def rename_car_images(old_car_data, new_car_data, image_directory):
    """
    Renames car image files based on the matched new car IDs.
    Assumes image files are named like 'OLD_ID.jpg' or 'OLD_ID.png'.
    """
    new_car_map = {f"{car['car_name']} {car['model_variant']}": car['car_id'] for car in new_car_data}

    for old_car in old_car_data:
        full_match_key = old_car["full_match"]
        if full_match_key in new_car_map:
            old_image_id = old_car["image_old_id_from_src"]
            new_image_id = new_car_map[full_match_key] 

            # Find files that start with the old_image_id (e.g., OLD_ID.jpg, OLD_ID.png)
            # Use os.scandir for better performance on large directories
            found_image = False
            for entry in os.scandir(image_directory):
                if entry.is_file() and entry.name.startswith(old_image_id):
                    # Get the extension
                    name, ext = os.path.splitext(entry.name)
                    old_path = entry.path
                    new_path = os.path.join(image_directory, f"{new_image_id}{ext}")

                    try:
                        os.rename(old_path, new_path)
                        print(f"Renamed '{entry.name}' to '{os.path.basename(new_path)}'")
                        found_image = True
                    except OSError as e:
                        print(f"Error renaming {entry.name} to {os.path.basename(new_path)}: {e}")
                    # Assuming only one file per old_image_id, break after renaming
                    break
            if not found_image:
                print(f"No image found for old ID '{old_image_id}' in '{image_directory}'.")
        else:
            print(f"No new ID for {old_car['car_name']} {old_car['model_variant']}. Skipping image rename for {old_car['image_old_id_from_src']}")


if __name__ == "__main__":
    # Your provided old Car data string
    # Read old car definitions from a text file (recommended for larger inputs)
    try:
        with open("old_car_definitions.txt", "r", encoding="utf-8") as f:
            old_car_definitions_string = f.read()
    except FileNotFoundError:
        print("old_car_definitions.txt not found. Using a hardcoded string for demonstration.")

    # Define the directory where your car images are stored
    # IMPORTANT: Change this to your actual image directory!
    IMAGE_DIRECTORY = "car_img" # Example: "C:/Users/YourUser/Desktop/car_images" or "./images"

    # --- User-provided df_cars DataFrame ---
    # This DataFrame is expected to be created and populated in your environment
    # before running this script (e.g., in a preceding cell of a Jupyter Notebook).
    # For demonstration, I'm defining a sample 'rows' data here.
    # -------------------------------------

    # --- Step 1: Parse old car data ---
    old_cars = parse_old_car_data(old_car_definitions_string)
    print("--- Parsed Old Car Data ---")
    for car in old_cars:
        print(f"Old ID: {car['old_car_id']}, Car Name: {car['car_name']}, Model Variant: {car['model_variant']}")

    # --- Step 2: Get new car data ---
    # Pass the existing df_cars DataFrame to get_new_car_data
    new_cars = get_new_car_data(df_cars)
    print("\n--- New Car Data (from your 'database') ---")
    for car in new_cars:
        # Access elements as dictionary keys
        print(f"New ID: {car['car_id']}, Car Name: {car['car_name']}, Model Variant: {car['model_variant']}")

    # --- Step 3: Generate updated Car object definitions ---
    updated_car_definitions = generate_updated_car_definitions(old_cars, new_cars)
    print("\n--- Updated Car Definitions ---")
    # You can write these to a new file, e.g., "updated_car_definitions.txt"
    # with open("updated_car_definitions.txt", "w", encoding="utf-8") as f:
    #     for definition in updated_car_definitions:
    #         f.write(definition + "\n")
    for definition in updated_car_definitions:
        print(definition)

    # --- Step 4: Rename car image files (Optional but recommended) ---
    # Create the directory if it doesn't exist for testing
    if not os.path.exists(IMAGE_DIRECTORY):
        os.makedirs(IMAGE_DIRECTORY)
        print(f"\nCreated directory: {IMAGE_DIRECTORY} for testing image renaming.")
        # Create some dummy image files for testing the rename function
        for car in old_cars:
            dummy_image_path_jpg = os.path.join(IMAGE_DIRECTORY, f"{car['image_old_id_from_src']}.jpg")
            dummy_image_path_png = os.path.join(IMAGE_DIRECTORY, f"{car['image_old_id_from_src']}.png")
            if not os.path.exists(dummy_image_path_jpg):
                with open(dummy_image_path_jpg, 'w') as f:
                    f.write("dummy content")
                print(f"Created dummy image: {dummy_image_path_jpg}")
            if not os.path.exists(dummy_image_path_png):
                with open(dummy_image_path_png, 'w') as f:
                    f.write("dummy content")
                print(f"Created dummy image: {dummy_image_path_png}")
    print("\n--- Renaming Car Images ---")
    rename_car_images(old_cars, new_cars, IMAGE_DIRECTORY)
    print("\n--- Image renaming process complete. ---")
# Out:
# --- Parsed Old Car Data ---
# Old ID: ASPB4AFE6, Car Name: Ford, Model Variant: 1.5 Tdci Blu
# Old ID: KUV9B596A, Car Name: Mahindra, Model Variant: K4+ 6Str
# Old ID: INN3FACDA, Car Name: Toyota, Model Variant: 2.4 Vx 8 Str
# Old ID: CRE87FB16, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx
# Old ID: KUV14AC69, Car Name: Mahindra, Model Variant: K2 D 5Str Taxi
# Old ID: AUR23B2F5, Car Name: Hyundai, Model Variant: Sx 1.2 Petrol
# Old ID: BOL36C317, Car Name: Mahindra, Model Variant: Lx
# Old ID: XUV496500, Car Name: Mahindra, Model Variant: W9 At
# Old ID: GRA14E083, Car Name: Hyundai, Model Variant: Era T Crdi
# Old ID: GRAAA9EAD, Car Name: Hyundai, Model Variant: Sportz Amt 1.2 Vtvt
# Old ID: M448BF09, Car Name: Bmw, Model Variant: Coupe
# Old ID: 7-SF1F2DA, Car Name: Bmw, Model Variant: 730Ld Design Pure Excellence Signature
# Old ID: X40DE6F1, Car Name: Bmw, Model Variant: Xdrive30I M Sport X
# Old ID: X3237D1E, Car Name: Bmw, Model Variant: Xdrive20D Xline
# Old ID: 6-SDDB69A, Car Name: Bmw, Model Variant: 620D Gt Luxury Line
# Old ID: ZES6E9199, Car Name: Tata, Model Variant: Xm Diesel
#
# --- New Car Data (from your 'database') ---
# New ID: 7-SEECD6C, Car Name: Bmw, Model Variant: 730Ld Design Pure Excellence Signature
# New ID: AMA2E1405, Car Name: Honda, Model Variant: E Mt Petrol
# New ID: CIAEB8722, Car Name: Maruti Suzuki, Model Variant: 1.5L Zeta
# New ID: TUC7D2599, Car Name: Hyundai, Model Variant: 2Wd Mt Diesel
# New ID: VENCD8EAA, Car Name: Hyundai, Model Variant: 1.0 Turbo Gdi Mt Sx(O)
# New ID: TUVD4124B, Car Name: Mahindra, Model Variant: T8
# New ID: FOR010697, Car Name: Toyota, Model Variant: 2.7 4X2 At
# New ID: TIAA71C2C, Car Name: Tata, Model Variant: Revotron Xt
# New ID: NEXF8FF3B, Car Name: Tata, Model Variant: Xza Plus (O) Dual Tone
# New ID: ZES99DC2B, Car Name: Tata, Model Variant: Xm Petrol
# New ID: BAL16EF9E, Car Name: Maruti Suzuki, Model Variant: 1.2 Zeta Cvt
# New ID: X1F42080, Car Name: Bmw, Model Variant: Sdrive20D M Sport
# New ID: MARE9CF37, Car Name: Mahindra, Model Variant: M6 7 Str
# New ID: ELIEF0D92, Car Name: Hyundai, Model Variant: Asta (O) 1.2
# New ID: 6-SE9AF42, Car Name: Bmw, Model Variant: 630I Gt Luxury Line
# New ID: INN0B1B17, Car Name: Toyota, Model Variant: 2.4 Zx 7 Str
# New ID: MARBF47AF, Car Name: Mahindra, Model Variant: M8 7 Str
# New ID: SWIDB044B, Car Name: Maruti Suzuki, Model Variant: Zdi Plus Amt
# New ID: CRE3F4691, Car Name: Hyundai, Model Variant: 1.4 Crdi Ex
# New ID: MER0A5B29, Car Name: Mercedes-Benz, Model Variant: 300D
# New ID: BAL51D8B6, Car Name: Maruti Suzuki, Model Variant: 1.2 Delta
# New ID: XCE4E4F6E, Car Name: Hyundai, Model Variant: T+ Crdi
# New ID: ECOAA1329, Car Name: Ford, Model Variant: 1.5L Ti-Vct Trend
# New ID: GRACFB562, Car Name: Hyundai, Model Variant: Era T Cng Vtvt
# New ID: YAR4AAADD, Car Name: Toyota, Model Variant: G (O) Cvt
# New ID: ETI0AD596, Car Name: Toyota, Model Variant: G
# New ID: GLA09DEA3, Car Name: Toyota, Model Variant: G Mt
# New ID: NUVC0BE83, Car Name: Mahindra, Model Variant: N4 +
# New ID: AUR0261D9, Car Name: Hyundai, Model Variant: E 1.2 Petrol
# New ID: MER2A9C4E, Car Name: Mercedes-Benz, Model Variant: E200 Exclusive
# New ID: BRV44B461, Car Name: Honda, Model Variant: Vx Petrol
# New ID: ZES20B29C, Car Name: Tata, Model Variant: Xe Diesel
# New ID: LAN73449D, Car Name: Toyota, Model Variant: Vx
# New ID: VERE92A50, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx (O)
# New ID: ERT34992D, Car Name: Maruti Suzuki, Model Variant: Zxi Plus
# New ID: COR725120, Car Name: Toyota, Model Variant: Vl At Petrol
# New ID: SCO746E1C, Car Name: Mahindra, Model Variant: S5 2Wd
# New ID: CELF5B674, Car Name: Maruti Suzuki, Model Variant: Vxi
# New ID: XUV70924F, Car Name: Mahindra, Model Variant: W7
# New ID: DZIAC4D3C, Car Name: Maruti Suzuki, Model Variant: Vdi Amt
# New ID: ELIE9065B, Car Name: Hyundai, Model Variant: Magna Plus Crdi
# New ID: ELI97A88B, Car Name: Hyundai, Model Variant: Sportz Plus Cvt
# New ID: TIA4CDEB8, Car Name: Tata, Model Variant: Revotron Xz
# New ID: HEX3632BC, Car Name: Tata, Model Variant: Xt 4X2
# New ID: AMAB5E1CE, Car Name: Honda, Model Variant: V Mt Petrol
# New ID: ASP86F9BA, Car Name: Ford, Model Variant: 1.2 Ti-Vct Titanium Plus
# New ID: ALTBA388B, Car Name: Tata, Model Variant: Xz Petrol
# New ID: NEX78B1F9, Car Name: Tata, Model Variant: Xza Plus
# New ID: MER2DACD8, Car Name: Mercedes-Benz, Model Variant: 400D 4Matic Hip Hop Edition
# New ID: BALE293CC, Car Name: Maruti Suzuki, Model Variant: 1.2 Alpha Cvt
# New ID: KUVCDE0E4, Car Name: Mahindra, Model Variant: K2 D 6Str
# New ID: BRVB28230, Car Name: Honda, Model Variant: E Petrol
# New ID: CITD2A942, Car Name: Honda, Model Variant: Zx Cvt Petrol
# New ID: CIAF50353, Car Name: Maruti Suzuki, Model Variant: 1.5L Alpha Smart Hybrid
# New ID: VITA2B3B9, Car Name: Maruti Suzuki, Model Variant: Zdi Ags
# New ID: FOR79F13A, Car Name: Toyota, Model Variant: 2.8 4X2 At
# New ID: XCE9EB1B0, Car Name: Hyundai, Model Variant: S At 1.2
# New ID: VITE8F648, Car Name: Maruti Suzuki, Model Variant: Zdi+ Ags
# New ID: SWI715B2E, Car Name: Maruti Suzuki, Model Variant: Zdi Amt
# New ID: ALTD130A1, Car Name: Mahindra, Model Variant: 4Wd At
# New ID: KUV0BCBAE, Car Name: Mahindra, Model Variant: K2 6Str
# New ID: CEL676BB4, Car Name: Maruti Suzuki, Model Variant: H2
# New ID: ELIAFE254, Car Name: Hyundai, Model Variant: Sportz Plus Crdi
# New ID: TIG7E97CE, Car Name: Tata, Model Variant: Revotron Xz
# New ID: DZIFCE5A4, Car Name: Maruti Suzuki, Model Variant: Zxi Plus Amt
# New ID: ALTFFD662, Car Name: Maruti Suzuki, Model Variant: Lxi
# New ID: YARF7244D, Car Name: Toyota, Model Variant: V (O)
# New ID: VER18E7D5, Car Name: Hyundai, Model Variant: 1.6 Crdi Sx(O) At
# New ID: BAL7C543D, Car Name: Maruti Suzuki, Model Variant: 1.3 Sigma
# New ID: AMA7B92EC, Car Name: Honda, Model Variant: Vx Mt Petrol
# New ID: XUV5B4B29, Car Name: Mahindra, Model Variant: W7
# New ID: VER5BEE76, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx(O) At
# New ID: ETI742E41, Car Name: Toyota, Model Variant: Vd
# New ID: AMA4E6650, Car Name: Honda, Model Variant: Vx Mt Diesel
# New ID: INNA52ED5, Car Name: Toyota, Model Variant: 2.4 G Plus 7 Str
# New ID: KUVF9D215, Car Name: Mahindra, Model Variant: K8 D 5Str
# New ID: XCE8EA8B4, Car Name: Hyundai, Model Variant: Sx 1.2
# New ID: SAN08648F, Car Name: Hyundai, Model Variant: Sportz Mt
# New ID: CIAC9E71E, Car Name: Maruti Suzuki, Model Variant: 1.5L Delta At Smart Hybrid
# New ID: SWI97592E, Car Name: Maruti Suzuki, Model Variant: Zxi Amt
# New ID: CRE87FB16, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx
# New ID: FIG7BAB10, Car Name: Ford, Model Variant: Ambiente 1.5 Tdci
# New ID: ENDE83EF4, Car Name: Ford, Model Variant: 3.2L 4X4 At Titanium Plus
# New ID: JAZC7BB94, Car Name: Honda, Model Variant: Vx Petrol
# New ID: ALTF5C40B, Car Name: Tata, Model Variant: Xz Diesel
# New ID: ASP4273C6, Car Name: Ford, Model Variant: 1.5 Tdci Blu
# New ID: KUV15B780, Car Name: Mahindra, Model Variant: K2 D 5Str Taxi
# New ID: CITFCE419, Car Name: Honda, Model Variant: Vx Cvt Petrol
# New ID: ELI653729, Car Name: Hyundai, Model Variant: Era 1.4 Crdi
# New ID: MAR804664, Car Name: Mahindra, Model Variant: M4 8 Str
# New ID: NUVC71C99, Car Name: Mahindra, Model Variant: N8
# New ID: CIABF39B1, Car Name: Maruti Suzuki, Model Variant: 1.5L Zeta Smart Hybrid
# New ID: ETI8FC42E, Car Name: Toyota, Model Variant: G
# New ID: X30545E9, Car Name: Bmw, Model Variant: Xdrive 20D Luxury Line
# New ID: KUVB963CD, Car Name: Mahindra, Model Variant: K8 5Str
# New ID: INN6A52F3, Car Name: Toyota, Model Variant: 2.7 Gx At 7 Str
# New ID: INN4F5FEE, Car Name: Toyota, Model Variant: 2.4 Gx 7 Str
# New ID: SCO243398, Car Name: Mahindra, Model Variant: S11 2Wd
# New ID: ALT995023, Car Name: Tata, Model Variant: Xe Petrol
# New ID: SANB09307, Car Name: Hyundai, Model Variant: Magna Mt Cng
# New ID: GRA8043B0, Car Name: Hyundai, Model Variant: Era T Vtvt
# New ID: HEX40E0A4, Car Name: Tata, Model Variant: Xm 4X2
# New ID: WR-53FE32, Car Name: Honda, Model Variant: Exclusive Edition Diesel
# New ID: ASPCF9DE2, Car Name: Ford, Model Variant: 1.2 Ti-Vct Blu
# New ID: ASPCE0A99, Car Name: Ford, Model Variant: 1.5 Tdci Titanium
# New ID: VIT32FD77, Car Name: Maruti Suzuki, Model Variant: Vdi
# New ID: MER387F5E, Car Name: Mercedes-Benz, Model Variant: C 43 Amg
# New ID: BRV549842, Car Name: Honda, Model Variant: V Petrol
# New ID: 3-SE15211, Car Name: Bmw, Model Variant: 320D Sport
# New ID: CREE5C29C, Car Name: Hyundai, Model Variant: Sports Edition Petrol
# New ID: GRA8CC9B7, Car Name: Hyundai, Model Variant: 1.2 Kappa Vtvt Sportz Dual Tone
# New ID: AMA47B202, Car Name: Honda, Model Variant: V Mt Diesel
# New ID: KUV502A51, Car Name: Mahindra, Model Variant: K6+ 6Str
# New ID: TIAF6CA03, Car Name: Tata, Model Variant: Revotron Xz Plus Dual Tone
# New ID: DZIFC03BD, Car Name: Maruti Suzuki, Model Variant: Zxi
# New ID: GLA2D0C7D, Car Name: Toyota, Model Variant: G Hybrid
# New ID: MER988195, Car Name: Mercedes-Benz, Model Variant: 200 Progressive
# New ID: HEX2ED683, Car Name: Tata, Model Variant: Xt 4X4
# New ID: TIA96D56F, Car Name: Tata, Model Variant: Revotron Xz Plus
# New ID: NEX885499, Car Name: Tata, Model Variant: Xza Plus (O) Diesel
# New ID: SWIF9D855, Car Name: Maruti Suzuki, Model Variant: Vdi
# New ID: MER2C6327, Car Name: Mercedes-Benz, Model Variant: B 180 Sport
# New ID: AMA04D4E3, Car Name: Honda, Model Variant: Ace Edition Cvt Diesel
# New ID: X3D243BE, Car Name: Bmw, Model Variant: Xdrive 30I Luxury Line
# New ID: BOL4E431C, Car Name: Tata, Model Variant: Xms Diesel
# New ID: MERF70F6D, Car Name: Mercedes-Benz, Model Variant: S 450
# New ID: GRA76E1C4, Car Name: Hyundai, Model Variant: Asta 1.2 Crdi
# New ID: HARB0F612, Car Name: Tata, Model Variant: Revotorq Xm
# New ID: CIT76640D, Car Name: Honda, Model Variant: V Mt Petrol
# New ID: CELF4D7E0, Car Name: Maruti Suzuki, Model Variant: Vxi Amt
# New ID: AUR78C77F, Car Name: Hyundai, Model Variant: Sx 1.2 Petrol
# New ID: ASPB36EFE, Car Name: Ford, Model Variant: 1.5 Tdci Titanium Plus
# New ID: CIAE200C2, Car Name: Maruti Suzuki, Model Variant: 1.5L Sigma Smart Hybrid
# New ID: VER0C51B4, Car Name: Hyundai, Model Variant: 1.4 Crdi Ex
# New ID: MERC407FE, Car Name: Mercedes-Benz, Model Variant: R
# New ID: AUR69E1B7, Car Name: Hyundai, Model Variant: S 1.2 Amt Petrol
# New ID: AMA8158CC, Car Name: Honda, Model Variant: S Mt Diesel
# New ID: XUV87BE69, Car Name: Mahindra, Model Variant: W7 At
# New ID: WR-C6ECB7, Car Name: Honda, Model Variant: Edge Plus Edition Petrol
# New ID: MEREBBCB3, Car Name: Mercedes-Benz, Model Variant: Elite
# New ID: COR434A7B, Car Name: Toyota, Model Variant: G At Petrol
# New ID: MAR35919B, Car Name: Mahindra, Model Variant: M8 8 Str
# New ID: XUVCB183C, Car Name: Mahindra, Model Variant: G At
# New ID: XCE79D0A3, Car Name: Hyundai, Model Variant: T Crdi
# New ID: XUV91A662, Car Name: Mahindra, Model Variant: W9 At
# New ID: FIGD472EE, Car Name: Ford, Model Variant: Titanium Blu 1.5 Tdci
# New ID: MERB3DB7E, Car Name: Mercedes-Benz, Model Variant: Roadster
# New ID: VERBB5974, Car Name: Hyundai, Model Variant: 1.6 Crdi Sx Plus At
# New ID: INNA00EE1, Car Name: Toyota, Model Variant: Touring Sport 2.7 Zx At 7 Str
# New ID: DZIF7680F, Car Name: Maruti Suzuki, Model Variant: Zxi Plus
# New ID: NEX5A0641, Car Name: Tata, Model Variant: Xza Plus (O) Diesel Dual Tone
# New ID: KUVF621EB, Car Name: Mahindra, Model Variant: K8 D 6Str
# New ID: NEX5843E0, Car Name: Tata, Model Variant: Xz Plus (O)
# New ID: NEX29A0EB, Car Name: Tata, Model Variant: Xz Plus
# New ID: MERFF3232, Car Name: Mercedes-Benz, Model Variant: E220D Expression
# New ID: GRAEFAC36, Car Name: Hyundai, Model Variant: 1.2 Kappa Vtvt Magna
# New ID: TUV35F9B0, Car Name: Mahindra, Model Variant: P8
# New ID: GRAEE77B5, Car Name: Hyundai, Model Variant: Sportz Amt 1.2 Vtvt
# New ID: VIT5DAF81, Car Name: Maruti Suzuki, Model Variant: Vdi Ags
# New ID: YARA43F9E, Car Name: Toyota, Model Variant: Vx Cvt
# New ID: ETI739807, Car Name: Toyota, Model Variant: Gx
# New ID: FIGAF0894, Car Name: Ford, Model Variant: Ambiente 1.2 Ti-Vct
# New ID: INN1F29A7, Car Name: Toyota, Model Variant: Touring Sport 2.7 Vx 7 Str
# New ID: ECOF3E42E, Car Name: Ford, Model Variant: 1.5L Tdci Trend
# New ID: AMAF76111, Car Name: Honda, Model Variant: Exclusive Edition Diesel
# New ID: BOL916198, Car Name: Tata, Model Variant: Xe Petrol
# New ID: DZI29A524, Car Name: Maruti Suzuki, Model Variant: Ldi
# New ID: NAN742413, Car Name: Tata, Model Variant: Emax Xm
# New ID: ECO78BB5B, Car Name: Ford, Model Variant: 1.5L Ti-Vct Titanium Plus At
# New ID: AUR1F8EC9, Car Name: Hyundai, Model Variant: Sx Plus 1.0 Petrol
# New ID: ECO8339F7, Car Name: Ford, Model Variant: 1.5L Tdci Titanium Plus
# New ID: VIT5C12D5, Car Name: Maruti Suzuki, Model Variant: Zdi+
# New ID: ASP66EF12, Car Name: Ford, Model Variant: 1.2 Ti-Vct Ambiente
# New ID: CR-6A8A5A, Car Name: Honda, Model Variant: 2Wd Diesel At
# New ID: YAR1F1FE8, Car Name: Toyota, Model Variant: J Cvt
# New ID: 7-S52C408, Car Name: Bmw, Model Variant: 730Ld Design Pure Excellence
# New ID: INN235C36, Car Name: Toyota, Model Variant: 2.7 Gx Mt 8 Str
# New ID: CEL4724E6, Car Name: Maruti Suzuki, Model Variant: Zxi Amt
# New ID: BOL97CA6E, Car Name: Tata, Model Variant: Xms Petrol
# New ID: ERTC6807C, Car Name: Maruti Suzuki, Model Variant: Vxi
# New ID: INN819516, Car Name: Toyota, Model Variant: 2.7 Gx Mt 7 Str
# New ID: MAR50EED8, Car Name: Mahindra, Model Variant: M4 7 Str
# New ID: NEX62E080, Car Name: Tata, Model Variant: Xe Diesel
# New ID: HEX79CE26, Car Name: Tata, Model Variant: Xm Plus 4X2
# New ID: THA24E9A8, Car Name: Mahindra, Model Variant: 700 Special Edition
# New ID: ERTDD49EE, Car Name: Maruti Suzuki, Model Variant: Vxi At
# New ID: MAR078830, Car Name: Mahindra, Model Variant: M2 7 Str
# New ID: SAND97683, Car Name: Hyundai, Model Variant: Magna Mt
# New ID: MER8926E3, Car Name: Mercedes-Benz, Model Variant: E 63 S Amg
# New ID: I209FA370, Car Name: Hyundai, Model Variant: 1.4 Sx
# New ID: GRA51D88D, Car Name: Hyundai, Model Variant: Era T+ Vtvt
# New ID: YAR26F039, Car Name: Toyota, Model Variant: V (O) Cvt
# New ID: CORFFA194, Car Name: Toyota, Model Variant: G Petrol
# New ID: WR-54D41B, Car Name: Honda, Model Variant: Vx Diesel
# New ID: CRE72C9DF, Car Name: Hyundai, Model Variant: 1.6 Vtvt E Plus
# New ID: ASPE91A84, Car Name: Ford, Model Variant: 1.2 Ti-Vct Titanium
# New ID: IGNB9C295, Car Name: Maruti Suzuki, Model Variant: Sigma 1.2 Mt
# New ID: VER074251, Car Name: Hyundai, Model Variant: 1.4 Vtvt E
# New ID: DZI1E784A, Car Name: Maruti Suzuki, Model Variant: Vxi Amt
# New ID: VER73EE8A, Car Name: Mahindra, Model Variant: 1.5 D6 Bs-Iv
# New ID: XUVBBA650, Car Name: Mahindra, Model Variant: W3
# New ID: X57690EC, Car Name: Bmw, Model Variant: Xdrive40I M Sport
# New ID: CEL5AB187, Car Name: Maruti Suzuki, Model Variant: Vxi At
# New ID: X408CC6C, Car Name: Bmw, Model Variant: Xdrive30D M Sport X
# New ID: MERDCF0C7, Car Name: Mercedes-Benz, Model Variant: C 200 Prime
# New ID: GRA6F547A, Car Name: Hyundai, Model Variant: Era 1.2 Vtvt
# New ID: XCE6E822E, Car Name: Hyundai, Model Variant: T+
# New ID: ETIAC85ED, Car Name: Toyota, Model Variant: V
# New ID: IGN4D762E, Car Name: Maruti Suzuki, Model Variant: Zeta 1.2 Mt
# New ID: CIVAC65B1, Car Name: Honda, Model Variant: 1.6 Zx Mt
# New ID: INN120D3C, Car Name: Toyota, Model Variant: 2.7 Gx At 8 Str
# New ID: MER34C15F, Car Name: Mercedes-Benz, Model Variant: 300D 4Matic
# New ID: GRAD6AA40, Car Name: Hyundai, Model Variant: Sportz 1.2 Vtvt
# New ID: 6-SDDB69A, Car Name: Bmw, Model Variant: 620D Gt Luxury Line
# New ID: SWI324005, Car Name: Maruti Suzuki, Model Variant: Vdi Amt
# New ID: SWI5244AD, Car Name: Maruti Suzuki, Model Variant: Zxi Plus
# New ID: KUV6B5ED3, Car Name: Mahindra, Model Variant: K2 6Str Cng Taxi
# New ID: ZES51697A, Car Name: Tata, Model Variant: Xta Diesel
# New ID: CEL09DFB1, Car Name: Maruti Suzuki, Model Variant: Zxi (O)
# New ID: NEXC96574, Car Name: Tata, Model Variant: Xma
# New ID: BOL36C317, Car Name: Mahindra, Model Variant: Lx
# New ID: CREE6DD44, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx At
# New ID: ASP4DADF4, Car Name: Ford, Model Variant: 1.2 Ti-Vct Trend Plus
# New ID: SWIAC45A2, Car Name: Maruti Suzuki, Model Variant: Zdi
# New ID: XL6684483, Car Name: Maruti Suzuki, Model Variant: Alpha Mt
# New ID: MER93BC1E, Car Name: Mercedes-Benz, Model Variant: 200D
# New ID: GRA8F3665, Car Name: Hyundai, Model Variant: Era T Crdi
# New ID: CIA2EBEB8, Car Name: Maruti Suzuki, Model Variant: 1.5L Alpha
# New ID: INN99AE9C, Car Name: Toyota, Model Variant: Touring Sport 2.4 Vx 7 Str
# New ID: TUCA53870, Car Name: Hyundai, Model Variant: 2Wd At Gls Petrol
# New ID: BOLDED5D4, Car Name: Tata, Model Variant: Xe Diesel
# New ID: ERT4FD39D, Car Name: Maruti Suzuki, Model Variant: 1.5L Zdi Plus
# New ID: SCO2E1572, Car Name: Mahindra, Model Variant: S7 120 2Wd
# New ID: KUVBFDB2A, Car Name: Mahindra, Model Variant: K4+ 5Str
# New ID: MERA62EBE, Car Name: Mercedes-Benz, Model Variant: 45 Amg 4Matic
# New ID: SAN195B38, Car Name: Hyundai, Model Variant: Sportz Mt Cng
# New ID: 5-SBF7217, Car Name: Bmw, Model Variant: 530I M Sport
# New ID: MERC55767, Car Name: Mercedes-Benz, Model Variant: Amg G 63
# New ID: FRE091D08, Car Name: Ford, Model Variant: 1.5L Tdci Titanium
# New ID: CRE98E2EB, Car Name: Hyundai, Model Variant: 1.6 Crdi S At
# New ID: JAZE0A165, Car Name: Honda, Model Variant: Vx Diesel
# New ID: SAF0DB880, Car Name: Tata, Model Variant: 2.2 Ex 4X2
# New ID: HAR5D0A9D, Car Name: Tata, Model Variant: Revotorq Xz
# New ID: CIA0447B9, Car Name: Maruti Suzuki, Model Variant: 1.3L Zeta Smart Hybrid
# New ID: MER9D6457, Car Name: Mercedes-Benz, Model Variant: 63 Amg
# New ID: KUV401BC3, Car Name: Mahindra, Model Variant: K6+ D 6Str
# New ID: DZI726D7C, Car Name: Maruti Suzuki, Model Variant: Vxi
# New ID: ELI240546, Car Name: Hyundai, Model Variant: Sportz Plus Dual Tone
# New ID: XUVA7E2DC, Car Name: Mahindra, Model Variant: W11 (O) At
# New ID: MER4DD38C, Car Name: Mercedes-Benz, Model Variant: B 180 Night Edition
# New ID: MER742CA8, Car Name: Mercedes-Benz, Model Variant: C 220D Progressive
# New ID: GRA57348B, Car Name: Hyundai, Model Variant: 1.2 Kappa Vtvt Sportz
# New ID: NEX31E84A, Car Name: Tata, Model Variant: Xza Plus Dual Tone
# New ID: SWI083A0B, Car Name: Maruti Suzuki, Model Variant: Vxi Amt
# New ID: XL65EEB2F, Car Name: Maruti Suzuki, Model Variant: Zeta Mt
# New ID: X4DD2FE7, Car Name: Bmw, Model Variant: Xdrive30I M Sport X
# New ID: XCE2A505F, Car Name: Hyundai, Model Variant: Sx 1.2 Crdi (O)
# New ID: AMAE10BDE, Car Name: Honda, Model Variant: Exclusive Edition Petrol
# New ID: IGN57BE3E, Car Name: Maruti Suzuki, Model Variant: Delta 1.2 Mt
# New ID: CRE2BB99F, Car Name: Hyundai, Model Variant: 1.6 Crdi Sx Dual Tone
# New ID: CIAF71791, Car Name: Maruti Suzuki, Model Variant: 1.5L Zeta At Smart Hybrid
# New ID: FOR18E461, Car Name: Toyota, Model Variant: 2.8 4X4 Mt
# New ID: MERD323CD, Car Name: Mercedes-Benz, Model Variant: 45 Aero Edition
# New ID: JAZ588611, Car Name: Honda, Model Variant: V Petrol
# New ID: XUVBF5F27, Car Name: Mahindra, Model Variant: W11 (O)
# New ID: DZI8862BE, Car Name: Maruti Suzuki, Model Variant: Zdi Plus
# New ID: MERE812C4, Car Name: Mercedes-Benz, Model Variant: Amg S 63 Coupe
# New ID: TUC527142, Car Name: Hyundai, Model Variant: 4Wd At Gls Diesel
# New ID: ELI13123C, Car Name: Hyundai, Model Variant: Magna Plus
# New ID: MERA61610, Car Name: Mercedes-Benz, Model Variant: S
# New ID: M448BF09, Car Name: Bmw, Model Variant: Coupe
# New ID: INN4E157C, Car Name: Toyota, Model Variant: 2.4 G Plus 8 Str
# New ID: AMAE6D953, Car Name: Honda, Model Variant: V Cvt Diesel
# New ID: XUVC0515D, Car Name: Mahindra, Model Variant: G At
# New ID: MERE97BED, Car Name: Mercedes-Benz, Model Variant: E220D
# New ID: WR-ACCFB5, Car Name: Honda, Model Variant: S Diesel
# New ID: DZID397F5, Car Name: Maruti Suzuki, Model Variant: Zdi Amt
# New ID: VIT7A4E4F, Car Name: Maruti Suzuki, Model Variant: Zdi
# New ID: 5-S6C88E6, Car Name: Bmw, Model Variant: 530D M Sport
# New ID: INND71EAB, Car Name: Toyota, Model Variant: 2.4 Vx 7 Str
# New ID: MER4073F6, Car Name: Mercedes-Benz, Model Variant: C 220D Prime
# New ID: ASPF25AC3, Car Name: Ford, Model Variant: 1.5 Tdci Trend Plus
# New ID: ASP2B754F, Car Name: Ford, Model Variant: 1.2 Trend Plus Cng
# New ID: DZI143BCC, Car Name: Maruti Suzuki, Model Variant: Ldi
# New ID: CEL101AF1, Car Name: Maruti Suzuki, Model Variant: Lxi
# New ID: MER9D3DDD, Car Name: Mercedes-Benz, Model Variant: E220D Exclusive
# New ID: CIV60208E, Car Name: Honda, Model Variant: 1.8 Zx Cvt
# New ID: BRVC447EF, Car Name: Honda, Model Variant: V Diesel
# New ID: DZI875409, Car Name: Maruti Suzuki, Model Variant: Vdi
# New ID: 3-S3BFD5E, Car Name: Bmw, Model Variant: 320D Luxury Line
# New ID: ALT8FAD65, Car Name: Tata, Model Variant: Xt Diesel
# New ID: PLA6ED1C0, Car Name: Toyota, Model Variant: Vd
# New ID: CEL391B3A, Car Name: Maruti Suzuki, Model Variant: Zxi (Opt)
# New ID: KUVA993BD, Car Name: Mahindra, Model Variant: K6+ 5Str
# New ID: MER5BE75F, Car Name: Mercedes-Benz, Model Variant: B 200 Cdi Night Edition
# New ID: SWIDBD266, Car Name: Maruti Suzuki, Model Variant: Vxi
# New ID: TUCCD70BC, Car Name: Hyundai, Model Variant: 2Wd At Gl Diesel
# New ID: SCO00A8C3, Car Name: Mahindra, Model Variant: S9 2Wd
# New ID: FORCC7A75, Car Name: Toyota, Model Variant: 2.8 4X2 Mt
# New ID: BAL9A27FA, Car Name: Maruti Suzuki, Model Variant: 1.2 Delta Dualjet
# New ID: CIV9A4131, Car Name: Honda, Model Variant: 1.6 Vx Mt
# New ID: MERF59AEB, Car Name: Mercedes-Benz, Model Variant: E200
# New ID: NEX61C82C, Car Name: Tata, Model Variant: Xz Plus (O) Diesel Dual Tone
# New ID: ERT9AE9CD, Car Name: Maruti Suzuki, Model Variant: 1.5L Zdi
# New ID: BAL13CF23, Car Name: Maruti Suzuki, Model Variant: Rs 1.0
# New ID: VITD7B407, Car Name: Maruti Suzuki, Model Variant: Zdi+ Dual Tone
# New ID: ALT673C58, Car Name: Maruti Suzuki, Model Variant: H1
# New ID: ALT3BED23, Car Name: Tata, Model Variant: Xe Diesel
# New ID: ECODF7F2A, Car Name: Ford, Model Variant: 1.5L Ti-Vct Thunder Edition
# New ID: ZES6E9199, Car Name: Tata, Model Variant: Xm Diesel
# New ID: 7-S16D787, Car Name: Bmw, Model Variant: 740Li Design Pure Excellence Signature
# New ID: GRAF4ED3B, Car Name: Hyundai, Model Variant: Sportz Amt 1.2 Crdi
# New ID: XUV9DD332, Car Name: Mahindra, Model Variant: W11 At
# New ID: XUV300C28, Car Name: Mahindra, Model Variant: W11 (O) Awd
# New ID: MER6AC77D, Car Name: Mercedes-Benz, Model Variant: B 200 Cdi Sport
# New ID: XL6B8402D, Car Name: Maruti Suzuki, Model Variant: Alpha At
# New ID: XUV63BE68, Car Name: Mahindra, Model Variant: W11 (O) Awd At
# New ID: M2 01D6EF, Car Name: Bmw, Model Variant: Coupe
# New ID: XUVB515E5, Car Name: Mahindra, Model Variant: W11 (O) At
# New ID: MER85C08F, Car Name: Mercedes-Benz, Model Variant: 400 4Matic
# New ID: MAR98F85C, Car Name: Mahindra, Model Variant: M6 8 Str
# New ID: MERF08F29, Car Name: Mercedes-Benz, Model Variant: E200 Expression
# New ID: MAR1516CD, Car Name: Mahindra, Model Variant: M2 8 Str
# New ID: TUC5DF438, Car Name: Hyundai, Model Variant: 2Wd At Gl(O) Petrol
# New ID: XCEEC5DD3, Car Name: Hyundai, Model Variant: E Crdi
# New ID: NAN13BFA9, Car Name: Tata, Model Variant: Xma
# New ID: NANB4D555, Car Name: Tata, Model Variant: Xt
# New ID: ETI8EBF4E, Car Name: Toyota, Model Variant: V
# New ID: CIT242A99, Car Name: Honda, Model Variant: Zx Mt Diesel
# New ID: BALDB1407, Car Name: Maruti Suzuki, Model Variant: 1.2 Delta Cvt
# New ID: XYLA8F2A6, Car Name: Mahindra, Model Variant: H4 Abs Bs-Iv
# New ID: GRA710261, Car Name: Hyundai, Model Variant: Era T+ Crdi
# New ID: SAF545636, Car Name: Tata, Model Variant: 2.2 Vx 4X2 Varicor 400
# New ID: CEL1E7ADF, Car Name: Maruti Suzuki, Model Variant: Vxi (O) Mt
# New ID: AUR57CD1F, Car Name: Hyundai, Model Variant: Sx Plus 1.2 Amt Diesel
# New ID: INNF2C96A, Car Name: Toyota, Model Variant: 2.4 Vx 8 Str
# New ID: MER2FA6A7, Car Name: Mercedes-Benz, Model Variant: E350 D
# New ID: HEX326483, Car Name: Tata, Model Variant: Xe 4X2
# New ID: SCOBCFF2E, Car Name: Mahindra, Model Variant: S3 2Wd
# New ID: VENA748F2, Car Name: Hyundai, Model Variant: 1.2 Kappa Mt S
# New ID: NANA91547, Car Name: Tata, Model Variant: Xm
# New ID: FRE85F420, Car Name: Ford, Model Variant: 1.2L Ti-Vct Titanium
# New ID: XYLDA7D2C, Car Name: Mahindra, Model Variant: H8 Abs Airbags Bs-Iv
# New ID: MERB27930, Car Name: Mercedes-Benz, Model Variant: S560
# New ID: JAZ711386, Car Name: Honda, Model Variant: V Cvt
# New ID: CIT971F14, Car Name: Honda, Model Variant: Sv Mt Petrol
# New ID: SWI514553, Car Name: Maruti Suzuki, Model Variant: Zxi Plus Amt
# New ID: SCO97199F, Car Name: Mahindra, Model Variant: 2Wd Getaway
# New ID: AUR2EED1B, Car Name: Hyundai, Model Variant: S 1.2 Amt Diesel
# New ID: LANDFBF36, Car Name: Toyota, Model Variant: Vx L
# New ID: ENDCC930F, Car Name: Ford, Model Variant: 2.2L 4X2 At Titanium Plus
# New ID: CEL281A01, Car Name: Maruti Suzuki, Model Variant: Zxi
# New ID: NEX43331C, Car Name: Tata, Model Variant: Xe
# New ID: PLA4CE480, Car Name: Toyota, Model Variant: Gxd
# New ID: KUVF6B211, Car Name: Mahindra, Model Variant: K8 D 6 Str Dual Tone
# New ID: CEL34928C, Car Name: Maruti Suzuki, Model Variant: Vxi
# New ID: HEX57CB90, Car Name: Tata, Model Variant: Xta 4X2
# New ID: VERBD7DDC, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx Plus At
# New ID: ETIAB56F0, Car Name: Toyota, Model Variant: Gxd
# New ID: HARFBC5BF, Car Name: Tata, Model Variant: Revotorq Xz Dual Tone
# New ID: ASP377A96, Car Name: Ford, Model Variant: 1.5 Tdci Ambiente
# New ID: 5-SD0C2AF, Car Name: Bmw, Model Variant: 520D Luxury Line
# New ID: INNBB4745, Car Name: Toyota, Model Variant: 2.7 Zx At 7 Str
# New ID: AUR558176, Car Name: Hyundai, Model Variant: S 1.2 Petrol
# New ID: HAR0B6E86, Car Name: Tata, Model Variant: Revotorq Xe
# New ID: KUVA43CF5, Car Name: Mahindra, Model Variant: K4+ 6Str
# New ID: DZIF2B7DE, Car Name: Maruti Suzuki, Model Variant: Zxi At
# New ID: KUVACF4DE, Car Name: Mahindra, Model Variant: K2+ D 6Str
# New ID: 3-SA8D598, Car Name: Bmw, Model Variant: 330I M Sport
# New ID: TUC6AC6E7, Car Name: Hyundai, Model Variant: 2Wd At Gl Petrol
# New ID: XCEA04907, Car Name: Hyundai, Model Variant: E
# New ID: ELAA7538D, Car Name: Hyundai, Model Variant: Sx
# New ID: BOL72ADA4, Car Name: Tata, Model Variant: Xm Diesel
# New ID: WR-AD35C7, Car Name: Honda, Model Variant: V Diesel
# New ID: NEXA9E064, Car Name: Tata, Model Variant: Xz
# New ID: ZESBA19A2, Car Name: Tata, Model Variant: Xe Petrol
# New ID: SCO0D57EA, Car Name: Mahindra, Model Variant: S7 140 2Wd
# New ID: XCEADE2AA, Car Name: Hyundai, Model Variant: S 1.2 Crdi
# New ID: XL6722630, Car Name: Maruti Suzuki, Model Variant: Zeta At
# New ID: MERD14A2D, Car Name: Mercedes-Benz, Model Variant: C 300D Amg Line
# New ID: ECOA39DC4, Car Name: Ford, Model Variant: 1.5L Tdci Titanium
# New ID: NUVE5A8E3, Car Name: Mahindra, Model Variant: N6 Amt
# New ID: MERA38682, Car Name: Mercedes-Benz, Model Variant: 200 D Sport
# New ID: ERT87E2E0, Car Name: Maruti Suzuki, Model Variant: Zxi At
# New ID: VENBACBBD, Car Name: Hyundai, Model Variant: 1.0 Turbo Gdi Mt Sx Dual Tone
# New ID: ECO43A6CD, Car Name: Ford, Model Variant: 1.5L Tdci Ambiente
# New ID: BALE1859C, Car Name: Maruti Suzuki, Model Variant: 1.3 Delta
# New ID: INNF62538, Car Name: Toyota, Model Variant: 2.4 Gx 8 Str
# New ID: CREF52B5E, Car Name: Hyundai, Model Variant: 1.6 Crdi Sx At
# New ID: PLA846BB8, Car Name: Toyota, Model Variant: Vxd Limited Edition
# New ID: TUVEAA0A3, Car Name: Mahindra, Model Variant: T10 (O) Dual Tone
# New ID: CEL3DC571, Car Name: Maruti Suzuki, Model Variant: Vxi Amt (O)
# New ID: MER58727F, Car Name: Mercedes-Benz, Model Variant: 200 D Sport
# New ID: ELI998AA9, Car Name: Hyundai, Model Variant: Era 1.2
# New ID: MERAD2B26, Car Name: Mercedes-Benz, Model Variant: 220 D 4Matic
# New ID: VER3AD51D, Car Name: Hyundai, Model Variant: 1.6 Vtvt Sx
# New ID: ERTC3A845, Car Name: Maruti Suzuki, Model Variant: Zxi
# New ID: ALTD4CBF8, Car Name: Tata, Model Variant: Xz (O) Diesel
# New ID: CIT6A9B69, Car Name: Honda, Model Variant: V Mt Diesel
# New ID: YAR59DCDC, Car Name: Toyota, Model Variant: G Cvt
# New ID: ETI4F7AB6, Car Name: Toyota, Model Variant: Dual Tone V
# New ID: GRA034114, Car Name: Hyundai, Model Variant: Asta 1.2 Vtvt
# New ID: NEX9E5144, Car Name: Tata, Model Variant: Xm Diesel
# New ID: MER4F8852, Car Name: Mercedes-Benz, Model Variant: S 350 D
# New ID: GRAAE3DF9, Car Name: Hyundai, Model Variant: Era T+ Cng Vtvt
# New ID: ENDDC83EE, Car Name: Ford, Model Variant: 2.2L 4X2 Mt Titanium
# New ID: MER860BD4, Car Name: Mercedes-Benz, Model Variant: 350 Cdi
# New ID: XUVB73EB7, Car Name: Mahindra, Model Variant: W11
# New ID: XCE8FC83F, Car Name: Hyundai, Model Variant: Sx 1.2 (O)
# New ID: BRV630E4C, Car Name: Honda, Model Variant: S Petrol
# New ID: KUVEB80B7, Car Name: Mahindra, Model Variant: K4+ D 5Str
# New ID: TUV27BDA6, Car Name: Mahindra, Model Variant: T6 Plus
# New ID: CIT1F3A21, Car Name: Honda, Model Variant: Sv Mt Diesel
# New ID: ZES386467, Car Name: Tata, Model Variant: Xt Diesel
# New ID: TIA981E22, Car Name: Tata, Model Variant: Revotron Xe
# New ID: DZIDA2839, Car Name: Maruti Suzuki, Model Variant: Zdi
# New ID: CIA45072E, Car Name: Maruti Suzuki, Model Variant: 1.3L Delta Smart Hybrid
# New ID: ALT15CCB5, Car Name: Tata, Model Variant: Xm Diesel
# New ID: ERT3C5FAD, Car Name: Maruti Suzuki, Model Variant: 1.5L Vdi
# New ID: BALABD7BD, Car Name: Maruti Suzuki, Model Variant: 1.3 Alpha
# New ID: BOLB6F0C1, Car Name: Tata, Model Variant: Xm Petrol
# New ID: VER3D0F31, Car Name: Hyundai, Model Variant: 1.4 Vtvt Ex
# New ID: VERECA232, Car Name: Hyundai, Model Variant: 1.6 Crdi Sx
# New ID: ERTFF09C4, Car Name: Maruti Suzuki, Model Variant: Lxi
# New ID: CEL01C5E4, Car Name: Maruti Suzuki, Model Variant: Vxi (O)
# New ID: VER812277, Car Name: Hyundai, Model Variant: 1.4 Crdi E
# New ID: KUVF6A68F, Car Name: Mahindra, Model Variant: K2+ 6Str
# New ID: INN25FE60, Car Name: Toyota, Model Variant: 2.7 Vx 7 Str
# New ID: ELI649D97, Car Name: Hyundai, Model Variant: Asta (O) Cvt
# New ID: ZES9FFF55, Car Name: Tata, Model Variant: Xt Petrol
# New ID: M5F22BC3, Car Name: Bmw, Model Variant: Competition
# New ID: X3237D1E, Car Name: Bmw, Model Variant: Xdrive20D Xline
# New ID: BRV903320, Car Name: Honda, Model Variant: S Diesel
# New ID: TUVE966F4, Car Name: Mahindra, Model Variant: T10 (O)
# New ID: FOR6A443B, Car Name: Toyota, Model Variant: Trd Celebratory Edition
# New ID: ASP554C1E, Car Name: Ford, Model Variant: 1.5 Tdci Trend
#
# --- Updated Car Definitions ---
# new Car("ASP4273C6", "Ford", "Aspire", "1.5 Tdci Blu", "D_LAKSHMIFOR001", 842400.00, 1498, 4, 40, "Diesel", "Sedan", 26.1, 5, "Electric Power", true, 100.0, 215.0, 5, "Manual", 2, true, true, true, true, "Blue", "Available", carImageService.getCarImageSrc("ASP4273C6"))
# new Car("KUVA43CF5", "Mahindra", "Kuv100 Nxt", "K4+ 6Str", "D_SIVAKUMARMAH001", 579645.00, 1198, 3, 35, "Petrol", "Hatchback", 18.15, 5, "Electric Power", true, 82.0, 115.0, 6, "Manual", 2, false, true, true, true, "Red", "Available", carImageService.getCarImageSrc("KUVA43CF5"))
# new Car("INNF2C96A", "Toyota", "Innova Crysta", "2.4 Vx 8 Str", "D_SENTHILTOY001", 1932000.00, 2393, 4, 55, "Diesel", "MUV", 15.4, 5, "Electric Power", true, 150.0, 343.0, 8, "Manual", 3, true, true, true, true, "Red", "Available", carImageService.getCarImageSrc("INNF2C96A"))
# new Car("VER3AD51D", "Hyundai", "Creta", "1.6 Vtvt Sx", "D_RAJESHHYU001", 1232534.00, 1591, 4, 55, "Petrol", "SUV", 15.29, 6, "Electric Power", true, 123.0, 151.0, 5, "Manual", 3, true, true, true, true, "Green", "Available", carImageService.getCarImageSrc("VER3AD51D"))
# new Car("KUV15B780", "Mahindra", "Kuv100 Nxt", "K2 D 5Str Taxi", "D_SIVAKUMARMAH001", 550155.00, 1198, 3, 35, "Diesel", "Hatchback", 25.32, 5, "Electric Power", true, 77.0, 190.0, 5, "Manual", 2, false, true, true, false, "Blue", "Available", carImageService.getCarImageSrc("KUV15B780"))
# new Car("AUR78C77F", "Hyundai", "Aura", "Sx 1.2 Petrol", "D_RAJESHHYU001", 729900.00, 1197, 4, 37, "Petrol", "Sedan", 20.5, 5, "Electric Power", true, 83.0, 114.0, 5, "Manual", 2, true, true, true, true, "Gold", "Available", carImageService.getCarImageSrc("AUR78C77F"))
# new Car("BOL36C317", "Mahindra", "Bolero Power Plus", "Lx", "D_SIVAKUMARMAH001", 749192.00, 1493, 4, 60, "Diesel", "SUV", 16.5, 5, "Electric Power", true, 70.0, 195.0, 7, "Manual", 3, true, true, true, true, "Beige", "Available", carImageService.getCarImageSrc("BOL36C317"))
# new Car("XUV91A662", "Mahindra", "Xuv500", "W9 At", "D_SIVAKUMARMAH001", 1710118.00, 2179, 4, 70, "Diesel", "SUV", 16.0, 6, "Electric Power", true, 155.0, 330.0, 7, "Automatic", 3, true, true, true, true, "Beige", "Available", carImageService.getCarImageSrc("XUV91A662"))
# new Car("GRA8F3665", "Hyundai", "Grand I10 Prime", "Era T Crdi", "D_PRIYAHYU001", 551530.00, 1120, 3, 43, "Diesel", "Hatchback", 24.0, 5, "Electric Power", true, 71.0, 16.3, 5, "Manual", 2, true, true, false, false, "Brown", "Available", carImageService.getCarImageSrc("GRA8F3665"))
# new Car("GRAEE77B5", "Hyundai", "Grand I10 Nios", "Sportz Amt 1.2 Vtvt", "D_PRIYAHYU001", 703350.00, 1197, 4, 37, "Petrol", "Hatchback", 20.7, 5, "Electric Power", true, 83.0, 114.0, 5, "Automatic", 3, true, true, true, true, "Maroon", "Available", carImageService.getCarImageSrc("GRAEE77B5"))
# new Car("M2 01D6EF", "Bmw", "M4", "Coupe", "D_SHANTHIBMW001", 13590000.00, 2979, 6, 60, "Petrol", "Coupe", 10.75, 7, "Electric Power", true, 431.0, 550.0, 4, "Automatic", 2, true, true, true, true, "Pink", "Available", carImageService.getCarImageSrc("M2 01D6EF"))
# new Car("7-SEECD6C", "Bmw", "7-Series", "730Ld Design Pure Excellence Signature", "D_SHANTHIBMW001", 13200000.00, 2993, 6, 78, "Diesel", "Sedan", 17.66, 8, "Hydraulic Power", true, 265.0, 620.0, 4, "Automatic", 3, true, true, true, true, "Blue", "Available",carImageService.getCarImageSrc("7-SEECD6C"))
# new Car("X4DD2FE7", "Bmw", "X4", "Xdrive30I M Sport X", "D_SHANTHIBMW001", 6350000.00, 1998, 6, 68, "Petrol", "SUV", 13.32, 8, "Electric Power", true, 248.0, 350.0, 5, "Automatic", 2, true, true, true, true, "Maroon", "Available",carImageService.getCarImageSrc("X4DD2FE7"))
# new Car("X3237D1E", "Bmw", "X3", "Xdrive20D Xline", "D_SHANTHIBMW001", 5600000.00, 1995, 4, 67, "Diesel", "SUV", 18.56, 8, "Electric Power", true, 190.0, 400.0, 5, "Automatic", 2, true, true, true, true, "Pink", "Available",carImageService.getCarImageSrc("X3237D1E"))
# new Car("6-SDDB69A", "Bmw", "6-Series", "620D Gt Luxury Line", "D_SURESHBMW001", 6440000.00, 1995, 4, 66, "Diesel", "Sedan", 21.76, 8, "Electric Power", true, 188.0, 400.0, 4, "Automatic", 2, true, true, true, true, "yellow", "Sold out",carImageService.getCarImageSrc("6-SDDB69A"))
# new Car("ALT15CCB5", "Tata", "Zest", "Xm Diesel", "D_ARUNTAT002", 767317.00, 1248, 4, 44, "Diesel", "Sedan", 23.0, 5, "Electric Power", true, 75.0, 190.0, 5, "Manual", 2, true, true, true, false, "Beige", "Available", carImageService.getCarImageSrc("ALT15CCB5"))
#
# Created directory: car_img for testing image renaming.
# Created dummy image: car_img\ASPB4AFE6.jpg
# Created dummy image: car_img\ASPB4AFE6.png
# Created dummy image: car_img\KUV9B596A.jpg
# Created dummy image: car_img\KUV9B596A.png
# Created dummy image: car_img\INN3FACDA.jpg
# Created dummy image: car_img\INN3FACDA.png
# Created dummy image: car_img\CRE87FB16.jpg
# Created dummy image: car_img\CRE87FB16.png
# Created dummy image: car_img\KUV14AC69.jpg
# Created dummy image: car_img\KUV14AC69.png
# Created dummy image: car_img\AUR23B2F5.jpg
# Created dummy image: car_img\AUR23B2F5.png
# Created dummy image: car_img\BOL36C317.jpg
# Created dummy image: car_img\BOL36C317.png
# Created dummy image: car_img\XUV496500.jpg
# Created dummy image: car_img\XUV496500.png
# Created dummy image: car_img\GRA14E083.jpg
# Created dummy image: car_img\GRA14E083.png
# Created dummy image: car_img\GRAAA9EAD.jpg
# Created dummy image: car_img\GRAAA9EAD.png
# Created dummy image: car_img\M448BF09.jpg
# Created dummy image: car_img\M448BF09.png
# Created dummy image: car_img\7-SF1F2DA.jpg
# Created dummy image: car_img\7-SF1F2DA.png
# Created dummy image: car_img\X40DE6F1.jpg
# Created dummy image: car_img\X40DE6F1.png
# Created dummy image: car_img\X3237D1E.jpg
# Created dummy image: car_img\X3237D1E.png
# Created dummy image: car_img\6-SDDB69A.jpg
# Created dummy image: car_img\6-SDDB69A.png
# Created dummy image: car_img\ZES6E9199.jpg
# Created dummy image: car_img\ZES6E9199.png
#
# --- Renaming Car Images ---
# Renamed 'ASPB4AFE6.jpg' to 'ASP4273C6.jpg'
# Renamed 'KUV9B596A.jpg' to 'KUVA43CF5.jpg'
# Renamed 'INN3FACDA.jpg' to 'INNF2C96A.jpg'
# Renamed 'CRE87FB16.jpg' to 'VER3AD51D.jpg'
# Renamed 'KUV14AC69.jpg' to 'KUV15B780.jpg'
# Renamed 'AUR23B2F5.jpg' to 'AUR78C77F.jpg'
# Renamed 'BOL36C317.jpg' to 'BOL36C317.jpg'
# Renamed 'XUV496500.jpg' to 'XUV91A662.jpg'
# Renamed 'GRA14E083.jpg' to 'GRA8F3665.jpg'
# Renamed 'GRAAA9EAD.jpg' to 'GRAEE77B5.jpg'
# Renamed 'M448BF09.jpg' to 'M2 01D6EF.jpg'
# Renamed '7-SF1F2DA.jpg' to '7-SEECD6C.jpg'
# Renamed 'X40DE6F1.jpg' to 'X4DD2FE7.jpg'
# Renamed 'X3237D1E.jpg' to 'X3237D1E.jpg'
# Renamed '6-SDDB69A.jpg' to '6-SDDB69A.jpg'
# Renamed 'ZES6E9199.jpg' to 'ALT15CCB5.jpg'
#
# --- Image renaming process complete. ---

# %%
# Display car name (brand), model, and variant for each row
for row in rows[:5]:
    print(f"{row[1]} {row[2]} {row[3]}")
# Out:
# Hyundai Aura S 1.2 Amt Petrol
# Mercedes-Benz Mercedes-Benz G-Class Amg G 63
# Tata Nexon Xza Plus (O) Diesel
# Hyundai Elite I20 Sportz Plus Crdi
# Bmw 6-Series 620D Gt Luxury Line
